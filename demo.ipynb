# %% [markdown]
# # Python Benchmark Demo
# Equivalent cells to demo.ybk for comparison

# %%
import sys

greeting = "Hello from Python 🐍"
version = sys.version
print(greeting)
print("Python version:", version)
# Out:
# SyntaxError: Unexpected identifier 'sys'. import call expects one or two arguments.
#     at <parse> (:4)
#     at AsyncFunction (unknown)
#     at executeCode (/home/nxank4/personal/yeastbook/packages/app/src/kernel/execute.ts:69:20)
#     at message (/home/nxank4/personal/yeastbook/packages/app/src/server.ts:468:36)

# %%
# Variable greeting from cell 1 persists
greeting + " — context works!"

# %%
import urllib.request
import json

res = urllib.request.urlopen("https://jsonplaceholder.typicode.com/todos/1")
todo = json.loads(res.read())
todo

# %%
users = [
    {"name": "Alice", "age": 30, "role": "admin"},
    {"name": "Bob", "age": 25, "role": "user"},
    {"name": "Charlie", "age": 35, "role": "user"},
]
users

# %%
import matplotlib.pyplot as plt

data = [12, 19, 8, 15, 22, 18, 25]
plt.figure(figsize=(8, 4))
plt.plot(data, marker='o', color='#D97706', linewidth=2)
plt.title("User Activity Q1")
plt.ylabel("Weekly activity")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Equivalent to console.table
data = [
    {"method": "GET", "endpoint": "/api/users", "ms": 12},
    {"method": "POST", "endpoint": "/api/login", "ms": 45},
    {"method": "DELETE", "endpoint": "/api/session", "ms": 8},
]

header = f"{'method':<8} | {'endpoint':<15} | {'ms':>4}"
sep = "-" * len(header)
rows = "\n".join(f"{r['method']:<8} | {r['endpoint']:<15} | {r['ms']:>4}" for r in data)
print(header)
print(sep)
print(rows)

# %%
import subprocess

result = subprocess.run(["ls", "-la"], capture_output=True, text=True)
print(result.stdout)

# %%
# ipywidgets equivalent
try:
    import ipywidgets as widgets
    slider = widgets.IntSlider(min=0, max=100, value=50, description="Threshold")
    display(slider)
except ImportError:
    print("ipywidgets not installed — run: pip install ipywidgets")

# %%
# pip install equivalent
import subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "more-itertools", "-q"])

# %%
from more_itertools import chunked
list(chunked([1, 2, 3, 4, 5, 6], 2))

# %%
import time

start = time.perf_counter()
total = 0
for i in range(10_000_000):
    total += i
end = time.perf_counter()

print(f"10M iterations: {(end - start) * 1000:.2f}ms")
print(f"Sum: {total}")
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/home/linuxbrew/.linuxbrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
undefined_variable.foo

# %%
from IPython.display import SVG, display

svg = """<svg width="200" height="100" xmlns="http://www.w3.org/2000/svg">
    <rect width="200" height="100" fill="#F7F4EF"/>
    <circle cx="50" cy="50" r="30" fill="#D97706"/>
    <text x="100" y="55" font-family="Inter" font-size="16" fill="#1A1714">Python</text>
</svg>"""
display(SVG(svg))
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/home/linuxbrew/.linuxbrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
